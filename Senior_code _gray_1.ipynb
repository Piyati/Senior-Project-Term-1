# %% [markdown]
# P => Piecewise Linear Contrast Stretching
#
# GHE => Global Histogram Equalization
#
# CLAHE => Contrast Limited Adaptive Histogram Equalization

# %% [markdown]
# # Function label and jpg and png

# %%
import os
import glob
import keras
import sklearn
import cv2 as cv2
import numpy as np
import pandas as pd
import PIL as Image
import seaborn as sns
import pathlib as path
import tensorflow as tf
import matplotlib as mpl
from datetime import datetime
import matplotlib.image as img
from keras import backend as k
from keras.models import Model
import matplotlib.pyplot as plt
from keras.utils import np_utils 
#from google.colab.patches import cv2_imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.datasets import fashion_mnist
from keras.layers.convolutional import  MaxPooling2D
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras import models, layers, optimizers, callbacks
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input
from tensorflow.keras.utils import to_categorical, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, ReLU,Flatten,Activation, GlobalAveragePooling2D, Input
# %matplotlib inline

# %%
# %load _utils
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from keras import backend as K

# Test
def print_hello():
    print('Hello')

# define a function to plot the result from training step
def show_result(history): 
    temph = history.history
    temp_loss = temph['loss']
    temp_acc = temph['acc']
    temp_vloss = temph['val_acc']
    temp_vacc = temph['val_acc']

    max_valacc = max(temp_vacc)
    max_index = temp_vacc.index(max_valacc)
    max_index
    # Print the result from the last epoch
    print('Highest validation accuracy in Epoch: %s'%str(max_index+1))
    print('Train accuracy: %s'%temp_acc[max_index])
    print('Validation accuracy: %s'%temp_vacc[max_index])
    print('--------------------------------------------------')
    print('Last train Epoch')
    print('Train accuracy: %s'%history.history['acc'][-1])
    print('Validation accuracy: %s'%history.history['val_acc'][-1])

    
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    
    epochs = range(1, len(loss) + 1)   
    
    # Define a subplot 
    fig, axs = plt.subplots(1,2,figsize=(15,4))
    
    # Plot loss
    loss_plot = axs[0]
    
    loss_plot.plot(epochs, loss, 'c--', label='Training loss')
    loss_plot.plot(epochs, val_loss, 'b', label='Validation loss')
    loss_plot.set_title('Training and validation loss')
    loss_plot.set_xlabel('Epochs')
    loss_plot.set_ylabel('Loss')
    loss_plot.legend()
    
    # Plot accuracy
    acc_plot = axs[1]
    
    acc_plot.plot(epochs, acc, 'c--', label='Training acc')
    acc_plot.plot(epochs, val_acc, 'b', label='Validation acc')
    acc_plot.set_title('Training and validation accuracy')
    acc_plot.set_xlabel('Epochs')
    acc_plot.set_ylabel('Accuracy')
    acc_plot.legend()

# Define an evaluation function to print the evaluation result
def evaluation_report(model,features,labels):
    
    # Calculate result
    result = model.evaluate(features,labels,verbose=False)
    
    # Predict and convert into a class
    pred_class = model.predict(features).argmax(axis=1)
    labels = labels.argmax(axis=1)
    # Show report
    print(confusion_matrix(labels,pred_class))
    print(classification_report(labels,pred_class))
    print("Loss: %s Accuracy: %s" %(result[0],result[1]))
    
    return pred_class


# Show a subplot of the incorrect predict data
def show_false_prediction(predict, feature, label, img_size=28, channel=1):

    false_pred = feature[(predict != label).tolist()]
    actual_label = label[(predict != label).tolist()]
    false_label = predict[(predict != label).tolist()]
    if channel == 3:
        false_pred = false_pred.reshape(false_pred.shape[0],img_size,img_size,channel)
    elif channel == 1:
        false_pred = false_pred.reshape(false_pred.shape[0],img_size,img_size)
    else:
        raise ValueError('Must be RGB or gray scale image')
    
    print(false_pred.shape)

    fig, ax = plt.subplots(3,10,figsize=(15,6))
    fig.suptitle('The incorrect prediction')

    for i in range(3):
        for j in range(10):
            ax[i,j].imshow(false_pred[j + i*10],cmap='gray')
            ax[i,j].set_title('Pred %s Act %s'%(false_label[j + i*10],actual_label[j + i*10]))
            
# Show activation value of each layer
def show_layer_activation(activation, model,num_layer,num_row=16):
    layer_names = []
    for layer in model.layers[:num_layer]:
        layer_names.append(layer.name)

    images_per_row = num_row
    for layer_name, layer_activation in zip(layer_names,activation):
        n_features = layer_activation.shape[-1]

        size = layer_activation.shape[1]

        n_cols = n_features//images_per_row
        display_grid = np.zeros((size * n_cols, images_per_row * size))

        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0,:,:,col*images_per_row + row]
                channel_image -= channel_image.mean()
                channel_image /= channel_image.std()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0,255).astype('uint8')
                display_grid[col*size:(col +1)*size,
                             row*size:(row+1)*size] = channel_image
        scale = 1./size
        plt.figure(figsize=(scale*display_grid.shape[1],
                           scale*display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
        
        
def deprocess_image(img):
    
    # Zero-centering and make sure that std is 0.1
    img -= img.mean()
    img /= (img.std() + 1e-5)
    img *= 0.1
    
    # Clips to [0,1]
    img += 0.5
    img = np.clip(img,0,1)
    
    # Convert to RGB array
    img *= 255
    img = np.clip(img,0,255).astype('uint8')
    
    return img

def generate_pattern(model, layer_name , filter_index, size=150):
    # Build the loss function that maximize the activation of the nth filter of the layer under consideration
    layer_output = model.get_layer(layer_name).output
    loss = K.mean(layer_output[:,:,:,filter_index])
    
    # Compute the gradient of the input picture with regard to this loss
    grads = K.gradients(loss, model.input)[0]
    
    # Normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) +1e-5)
    
    # Return the loss and gradient given the input picture
    iterate = K.function([model.input],[loss, grads])
    
    # Stars from a gray image with some noise
    input_img_data = np.random.random((1, size, size, 3)) * 20 + 128.
    
    # Run gradient ascent for 40 step
    step = 1.
    for i in range(40):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step
        
    img = input_img_data[0]
    return deprocess_image(img)

### feed layer name. ie, 'conv_1'
def visualize_filter(model,layer_name, size= 64, margin = 5):

    # Empty black image to store results
    results = np.zeros((8 * size + 7 * margin, 8 * size + 7 * margin, 3))

    # iterate over the row of result grid
    for i in range(8):
        # Iterate over the column of the result grid
        for j in range(8):
            # Generates the pattern for filter i + (j*8) in layer_name
            filter_img = generate_pattern(model, layer_name, i + (j*8), size=size)
            
            # Puts the result in the square (i,j) of the results grid
            horizontal_start = i * size + i * margin
            horizontal_end = horizontal_start + size
            vertical_start = j * size + j * margin
            vertical_end = vertical_start + size
            results[horizontal_start:horizontal_end,
                    vertical_start:vertical_end, :] = filter_img

    plt.figure(figsize=(20,20))
    plt.imshow(results)

# %%
from tqdm.notebook import tqdm
import os, fnmatch
from keras import backend as K
from pathlib import Path
# change sub directory in list
def dirToList(dir_path):
  
  #get path create list
  pth = os.listdir(path=dir_path)
  lst_dir = []

  for s in pth:
    temp = str(dir_path + '\\' + s + '\\')
    lst_dir.append(temp)
  
  #remove .csv
  for i in tqdm(range(len(lst_dir))):
    if lst_dir[i-1][len(lst_dir[i-1])-4:] == 'csv/':
      lst_dir.pop(i-1)
    if lst_dir[i-1][len(lst_dir[i-1])-4:] == 'md/':
      lst_dir.pop(i-1)

  return lst_dir
# map path to name
def mapName(lab_list, lab_dict):
  temp = []
  for i in tqdm(range(len(lab_list))):
    key_label = lab_dict[lab_list[i]]
    temp.append(key_label)
  return temp

# %% [markdown]
# #### label

# %%
header_list = ["Type", "Description"]
md = pd.read_csv('C:\\Users\\CPE\\Desktop\\senior2023\\fco metdata.csv', names=header_list)
md
# Out:
#   Type Description
# 0   ce     Cemento
# 1   os   Ossifying
# 2   fi     Fibrous

# %%
label_dict = dict(zip(md['Type'], md['Description']))
label_dict
# Out:
# {'ce': 'Cemento', 'os': 'Ossifying', 'fi': 'Fibrous'}

# %% [markdown]
# #### Import model

# %% [markdown]
# ##### model inceptionresnetv2

# %%
from tensorflow.keras.applications import InceptionResNetV2
from keras.models import Model
from keras.layers import Dense
from keras.layers import Flatten

# %%
def def_model():
    model = InceptionResNetV2(
    include_top=False, 
    input_shape=(224, 224, 3)
      )
    for layer in model.layers:
        layer.trainable = False
    flat1 = Flatten()(model.layers[-1].output)
  #full_conn = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat1)
    output = Dense(3, activation='softmax')(flat1)
	# define new model
    model = Model(inputs=model.inputs, outputs=output)
	# compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    model.save('/content/model/InceptionResNetV21.h5')
    model.summary()
    return model

# %% [markdown]
# ##### model xception

# %%
#load pre trained Xception model
model_xcep1 = keras.applications.Xception(weights='imagenet',include_top=True, input_shape=(299,299,3),classifier_activation=None)

# %%
for layer in model_xcep1.layers:
    layer.trainable = False
x = Flatten() (model_xcep1.output)
prediction1 = Dense(3, activation = 'softmax')(x)
xcep1_model = Model(inputs = model_xcep1.input, outputs = prediction1)
xcep1_model.compile (loss = 'categorical_crossentropy',optimizer = 'adam',metrics = ['acc'])

# %% [markdown]
# ##### model efficentnetb2

# %%
from keras.applications.efficientnet import EfficientNetB2

# %%
model_effi = tf.keras.applications.efficientnet.EfficientNetB2(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=(260,260,3),
    classifier_activation='softmax'
)
for layer in model_effi.layers:
    layer.trainable = False
x = Flatten() (model_effi.output)
prediction1 = Dense(3, activation = 'softmax')(x)
effi1_model = Model(inputs = model_effi.input, outputs = prediction1)
effi1_model.compile (loss = 'categorical_crossentropy',optimizer = 'adam',metrics = ['acc'])

# %% [markdown]
# # Gray

# %% [markdown]
# ### Train

# %%
sub_dir_train_gray = dirToList('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\train_cell')
sub_dir_train_gray
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 
c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_132_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_133_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_134_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_135_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_136_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_137_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_138_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_139_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_140_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_141_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_142_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_143_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_144_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_145_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_146_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_147_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_148_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_149_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_150_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_151_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_152_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_153_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_154_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_155_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_156_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_157_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_158_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_159_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_160_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_161_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_162_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_163_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_164_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_165_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_166_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_167_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_168_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_169_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_170_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_171_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_172_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_173_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_174_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_175_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_176_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_177_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_178_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_179_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_180_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_181_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_182_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_183_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_184_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_185_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_186_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_187_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_188_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_189_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_190_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_191_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_192_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_193_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_194_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_195_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_196_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_197_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_198_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_199_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_200_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_201_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_202_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_203_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_204_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_205_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_206_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_207_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_208_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_209_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_210_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_211_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_212_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_213_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_214_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_215_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_216_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_217_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_218_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_219_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_220_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_221_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_222_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_223_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_224_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_225_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_226_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_227_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_228_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_229_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_230_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_231_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_232_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_233_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_234_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_235_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_236_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_237_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_238_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_239_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_240_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_241_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_242_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_243_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_244_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_245_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_246_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_247_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_248_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_249_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_250_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_251_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_252_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_253_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_254_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/train_cell/os/os_255_d.png')]

# %%
all_path = []
all_index = []
for i in tqdm(range(len(sub_dir_train_gray))):
  temp = fnmatch.filter(os.listdir(sub_dir_train_gray[i]), "*.png")
  all_path.append(temp)
all_path_con =[item for sublist in all_path for item in sublist]
for i in tqdm(range(len(all_path_con))):
  index = all_path_con[i][:2]
  all_index.append(index)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/449 [00:00<?, ?it/s]

# %%
all_path_map_train_gray = mapName(all_index, label_dict)
all_path_map_train_gray[:10]
# Out:
#   0%|          | 0/449 [00:00<?, ?it/s]
# ['Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento',
#  'Cemento']

# %%
all_filepaths_df = pd.Series(all_filepaths_train_gray , name = 'filepath').astype(str)
all_path_map_df = pd.Series(all_path_map_train_gray, name = 'label')

all_df = pd.concat([all_filepaths_df, all_path_map_df], axis = 1)
all_df.shape
# Out:
# (449, 2)

# %%
all_df.head()
# Out:
#                                             filepath    label
# 0  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 1  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 2  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 3  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 4  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento

# %% [markdown]
# ### Test

# %%
sub_dir_test_gray = dirToList('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell')
sub_dir_test_gray

sub_dir_test_Path = Path('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell')
all_filepaths_test_gray = list(sub_dir_test_Path.glob(r'**\\*.png'))
all_filepaths_test_gray
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_001_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_002_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_003_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_004_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_005_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_006_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_007_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_008_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_009_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_010_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_011_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_012_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_013_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_014_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/ce/ce_015_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_001_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_002_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_003_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_004_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_005_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_006_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_007_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_008_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_009_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_010_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_011_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_012_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_013_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_014_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/fi/fi_015_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_001_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_002_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_003_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_004_a.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_005_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_006_b.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_007_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_008_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_009_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_010_c.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_011_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_012_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_013_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_014_d.png'),
#  WindowsPath('C:/Users/CPE/Desktop/senior2023/gray/test_cell/os/os_015_d.png')]

# %%
all_path_test = []
all_index_test = []
for i in tqdm(range(len(sub_dir_test_gray))):
  temp2 = fnmatch.filter(os.listdir(sub_dir_test_gray[i]), "*.png")
  all_path_test.append(temp2)
all_path_test_con =[item for sublist in all_path_test for item in sublist]
for i in tqdm(range(len(all_path_test_con))):
  index = all_path_test_con[i][:2]
  all_index_test.append(index)

all_path_test_map_gray= mapName(all_index_test, label_dict)
all_path_test_map_gray[:10]

all_filepaths_test_df = pd.Series(all_filepaths_test_gray, name = 'filepath').astype(str)
all_path_test_map_df = pd.Series(all_path_test_map_gray, name = 'label')

all_test_df = pd.concat([all_filepaths_test_df, all_path_test_map_df], axis = 1)
all_test_df.shape
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/45 [00:00<?, ?it/s]
#   0%|          | 0/45 [00:00<?, ?it/s]
# (45, 2)

# %%
all_test_df
# Out:
#                                              filepath      label
# 0   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 1   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 2   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 3   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 4   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 5   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 6   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 7   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 8   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 9   C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 10  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 11  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 12  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 13  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 14  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Cemento
# 15  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 16  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 17  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 18  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 19  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 20  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 21  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 22  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 23  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 24  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 25  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 26  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 27  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 28  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 29  C:\Users\CPE\Desktop\senior2023\gray\test_cell...    Fibrous
# 30  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 31  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 32  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 33  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 34  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 35  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 36  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 37  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 38  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 39  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 40  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 41  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 42  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 43  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying
# 44  C:\Users\CPE\Desktop\senior2023\gray\test_cell...  Ossifying

# %% [markdown]
# ### Validation

# %%
ce_train_data = all_df.loc[all_df['label'] == label_dict['ce']]
fi_train_data = all_df.loc[all_df['label'] == label_dict['fi']]
os_train_data = all_df.loc[all_df['label'] == label_dict['os']]

ce_tr, ce_va = train_test_split(ce_train_data, test_size = .05)
fi_tr, fe_va = train_test_split(fi_train_data, test_size = .45)
os_tr, os_va = train_test_split(os_train_data, test_size = .75)

# %%
df_train = pd.concat([ce_tr,fi_tr,os_tr])
print(df_train.shape)
df_train.head()
# Out:
# (198, 2)
#                                              filepath    label
# 28  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 67  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 10  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 32  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento
# 37  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Cemento

# %%
df_val = pd.concat([ce_va,fe_va,os_va])
print(df_val.shape)
df_val.sample(10)
# Out:
# (251, 2)
#                                               filepath      label
# 272  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 158  C:\Users\CPE\Desktop\senior2023\gray\train_cel...    Fibrous
# 147  C:\Users\CPE\Desktop\senior2023\gray\train_cel...    Fibrous
# 314  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 391  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 294  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 133  C:\Users\CPE\Desktop\senior2023\gray\train_cel...    Fibrous
# 425  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 296  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying
# 353  C:\Users\CPE\Desktop\senior2023\gray\train_cel...  Ossifying

# %% [markdown]
# ### Generator

# %%
IMAGE_SIZE = [224,224]
train_generator = ImageDataGenerator(
    rescale=1./255, #rescal Grayscale
    horizontal_flip = True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    vertical_flip = True
)
validation_generator = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    vertical_flip = True
)
test_generator = keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    vertical_flip = True
)

X_COL = 'filepath'
Y_COL = 'label'

training_set_gray = train_generator.flow_from_dataframe(
    dataframe = df_train,
    x_col = X_COL,
    y_col = Y_COL,
    target_size = IMAGE_SIZE,
    batch_size = 4,
    class_mode = 'categorical')



validation_set_gray = validation_generator.flow_from_dataframe(
    dataframe = df_val,
    x_col = X_COL,
    y_col = Y_COL,
    target_size = IMAGE_SIZE,
    batch_size = 4,
    class_mode = 'categorical')



test_set_gray = test_generator.flow_from_dataframe(
    dataframe = all_test_df,
    x_col = X_COL,
    y_col = Y_COL,
    target_size = IMAGE_SIZE,
    batch_size = 4,
    class_mode = 'categorical')
# Out:
# Found 198 validated image filenames belonging to 3 classes.
# Found 251 validated image filenames belonging to 3 classes.
# Found 45 validated image filenames belonging to 3 classes.

# %% [markdown]
# ### Model InceptionResNetV 2

# %%
incepv2_1 = def_model()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 111, 111, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 111, 111, 32  96         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 109, 109, 32  96         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 109, 109, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 109, 109, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 109, 109, 64  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 109, 109, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 54, 54, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 54, 54, 80)  240         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 54, 54, 80)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 52, 52, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 52, 52, 192)  576        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 52, 52, 192)  0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_10[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_13[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 96)  288         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_9[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_11[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_14[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_15[0][0]']
#
#  mixed_5b (Concatenate)         (None, 25, 25, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 32)  96          ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_17[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 32)  96          ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_16[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_21[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 25, 25, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 25, 25, 320)  0           ['block35_1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 32)  96          ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 25, 25, 48)  144         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_23[0][0]']
#
#  activation_22 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 32)  96          ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_22[0][0]']
#
#  activation_20 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_27[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 25, 25, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 25, 25, 320)  0           ['block35_2[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 25, 25, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 25, 25, 32)  96          ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 25, 25, 48)  144         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_29[0][0]']
#
#  activation_28 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 32)  96          ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 25, 25, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 25, 25, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_28[0][0]']
#
#  activation_26 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_29 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_33[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 25, 25, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 25, 25, 320)  0           ['block35_3[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 25, 25, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 25, 25, 32)  96          ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 25, 25, 48)  144         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_35[0][0]']
#
#  activation_34 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 25, 25, 32)  96          ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 25, 25, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 25, 25, 64)  192         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_34[0][0]']
#
#  activation_32 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_35 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_39[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 25, 25, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 25, 25, 320)  0           ['block35_4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 25, 25, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 25, 25, 32)  96          ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 25, 25, 48)  144         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_41[0][0]']
#
#  activation_40 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 25, 25, 32)  96          ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 25, 25, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 25, 25, 64)  192         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_40[0][0]']
#
#  activation_38 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_41 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_45[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 25, 25, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 25, 25, 320)  0           ['block35_5[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 25, 25, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 25, 25, 32)  96          ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 25, 25, 48)  144         ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_47[0][0]']
#
#  activation_46 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 25, 25, 32)  96          ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 25, 25, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 25, 25, 64)  192         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_46[0][0]']
#
#  activation_44 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_47 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_51[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 25, 25, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 25, 25, 320)  0           ['block35_6[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 25, 25, 32)  96          ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 25, 25, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 25, 25, 32)  96          ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 25, 25, 48)  144         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_53[0][0]']
#
#  activation_52 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 25, 25, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 25, 25, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 25, 25, 32)  96          ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_54 (BatchN  (None, 25, 25, 32)  96          ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 25, 25, 64)  192         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_52[0][0]']
#
#  activation_50 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_54[0][0]']
#
#  activation_53 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_57[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 25, 25, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 25, 25, 320)  0           ['block35_7[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 25, 25, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 25, 25, 32)  96          ['conv2d_61[0][0]']
#  ormalization)
#
# ...
#  Normalization)
#
#  activation_188 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_188[0][0]']
#
#  batch_normalization_193 (Batch  (None, 5, 5, 224)   672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_189[0][0]']
#
#  batch_normalization_191 (Batch  (None, 5, 5, 192)   576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 5, 5, 256)   768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_191[0][0]']
#
#  activation_190 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_194[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 5, 5, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 5, 5, 192)   576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_192[0][0]']
#
#  batch_normalization_197 (Batch  (None, 5, 5, 224)   672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_193[0][0]']
#
#  batch_normalization_195 (Batch  (None, 5, 5, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 5, 5, 256)   768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_195[0][0]']
#
#  activation_194 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_198[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 5, 5, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 5, 5, 192)   576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_196[0][0]']
#
#  batch_normalization_201 (Batch  (None, 5, 5, 224)   672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_197[0][0]']
#
#  batch_normalization_199 (Batch  (None, 5, 5, 192)   576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 5, 5, 256)   768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_199[0][0]']
#
#  activation_198 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_202[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 5, 5, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_204 (Batch  (None, 5, 5, 192)   576         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_204[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_200[0][0]']
#
#  batch_normalization_205 (Batch  (None, 5, 5, 224)   672         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_205[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_201[0][0]']
#
#  batch_normalization_203 (Batch  (None, 5, 5, 192)   576         ['conv2d_203[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 5, 5, 256)   768         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_203[0][0]']
#
#  activation_202 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_206[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 5, 5, 448)    0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 5, 5, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 5, 5, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 5, 5, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 5, 5, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 5, 5, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_2 (Flatten)            (None, 38400)        0           ['conv_7b_ac[0][0]']
#
#  dense_2 (Dense)                (None, 3)            115203      ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 54,451,939
# Trainable params: 115,203
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
#early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=5) 
mcp_save = ModelCheckpoint('history_inceptionresnetv2_gray_remake2_model.h5', save_best_only=True, monitor='val_loss')

history_inceptionresnetv2_gray_remake_model = incepv2_1.fit(
                      training_set_gray,
                      batch_size=4,
                      epochs=300,
                      validation_data = (validation_set_gray),
                      callbacks=[mcp_save]
                      )
# Out:
# Epoch 1/300
# 50/50 [==============================] - 48s 833ms/step - loss: 6.3921 - acc: 0.4899 - val_loss: 4.1143 - val_acc: 0.6414
# Epoch 2/300
# 50/50 [==============================] - 39s 796ms/step - loss: 3.1426 - acc: 0.7121 - val_loss: 1.2426 - val_acc: 0.8207
# Epoch 3/300
# 50/50 [==============================] - 38s 760ms/step - loss: 3.2336 - acc: 0.6919 - val_loss: 8.7666 - val_acc: 0.4223
# Epoch 4/300
# 50/50 [==============================] - 38s 779ms/step - loss: 4.0095 - acc: 0.7525 - val_loss: 1.0101 - val_acc: 0.8924
# Epoch 5/300
# 50/50 [==============================] - 37s 739ms/step - loss: 2.6430 - acc: 0.7828 - val_loss: 3.2963 - val_acc: 0.7092
# Epoch 6/300
# 50/50 [==============================] - 37s 744ms/step - loss: 2.1009 - acc: 0.8283 - val_loss: 2.9424 - val_acc: 0.7450
# Epoch 7/300
# 50/50 [==============================] - 37s 746ms/step - loss: 2.2072 - acc: 0.8030 - val_loss: 4.1068 - val_acc: 0.7012
# Epoch 8/300
# 50/50 [==============================] - 38s 772ms/step - loss: 2.3507 - acc: 0.8182 - val_loss: 1.4998 - val_acc: 0.8327
# Epoch 9/300
# 50/50 [==============================] - 38s 771ms/step - loss: 1.1748 - acc: 0.8737 - val_loss: 3.3883 - val_acc: 0.7530
# Epoch 10/300
# 50/50 [==============================] - 42s 855ms/step - loss: 2.1409 - acc: 0.8182 - val_loss: 1.2836 - val_acc: 0.9084
# Epoch 11/300
# 50/50 [==============================] - 41s 819ms/step - loss: 1.7527 - acc: 0.8434 - val_loss: 2.0273 - val_acc: 0.8327
# Epoch 12/300
# 50/50 [==============================] - 42s 853ms/step - loss: 0.9882 - acc: 0.8990 - val_loss: 3.5569 - val_acc: 0.7331
# Epoch 13/300
# 50/50 [==============================] - 42s 837ms/step - loss: 0.8502 - acc: 0.8990 - val_loss: 1.6155 - val_acc: 0.8924
# Epoch 14/300
# 50/50 [==============================] - 43s 877ms/step - loss: 1.2060 - acc: 0.8838 - val_loss: 2.5886 - val_acc: 0.8088
# Epoch 15/300
# 50/50 [==============================] - 42s 854ms/step - loss: 2.1940 - acc: 0.8333 - val_loss: 1.4339 - val_acc: 0.9203
# Epoch 16/300
# 50/50 [==============================] - 43s 866ms/step - loss: 2.2446 - acc: 0.8535 - val_loss: 1.8657 - val_acc: 0.8765
# Epoch 17/300
# --------------------------------------------------
# Last train Epoch
# Train accuracy: 0.9797979593276978
# Validation accuracy: 0.9521912336349487

# %%
inrn2_model_remake2 = models.load_model('history_inceptionresnetv2_gray_remake2_model.h5')
#evaluation_report(inrn2_model_clahe, test_set_clahe, all_test_df_clahe['label'])

# %%
result_remake22 = inrn2_model_remake2.evaluate(test_set_gray, verbose=0)

print("Test loss: {:.5f}".format(result_remake22[0]))
print("Test accuracy: {:.2f}".format(result_remake22[1]))
# Out:
# Test loss: 4.98303
# Test accuracy: 0.89

# %%
all_test_df["label"] = all_test_df["label"].replace({'ce' : 0, 'os' : 1, 'fi' : 2})

# %%
def predict_in(img_path,model):
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.show()

    img_array = image.img_to_array(img)
    img_batch = np.expand_dims(img_array, axis=0)
    img_preprocessed = preprocess_input(img_batch)

    pred_class = model.predict(img_preprocessed).argmax(axis =1)

    if pred_class == 0:
      text = 'There is a Cemento'
    elif pred_class == 1:
      text = 'There is a Ossifying'
    else:
      text = 'There is a Fibrous'
    
    
    print('%s '%(text))

# %%
predict_in('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\ce\\ce_002_b.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 2s 2s/step
# There is a Fibrous

# %%
predict_in('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\ce\\ce_001_a.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 140ms/step
# There is a Fibrous

# %%
predict_in('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\fi\\fi_001_a.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 129ms/step
# There is a Fibrous

# %%
predict_in('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\fi\\fi_002_a.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 127ms/step
# There is a Fibrous

# %%
def predictor(img, model):
    image = cv2.imread(img)
    image = cv2.resize(image, (224, 224))
    #image = np.array(image, dtype = 'float32')/255.0
    plt.imshow(image)
    image = image.reshape(1, 224,224,3)
    
    label_names = label_dict
    dict_class = dict(zip(list(range(len(label_names))), label_names))
    clas = model.predict(image).argmax()
    name = dict_class[clas]
    print('The given image is of \nClass: {0} \nSpecies: {1}'.format(clas, name))

# %%
predictor('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\fi\\fi_015_c.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 130ms/step
# The given image is of
# Class: 2
# Species: fi

# %%
predictor('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\os\\os_015_d.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 125ms/step
# The given image is of
# Class: 2
# Species: fi

# %%
predictor('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\os\\os_004_a.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 149ms/step
# The given image is of
# Class: 2
# Species: fi

# %%
predictor('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\os\\os_005_b.png',inrn2_model_remake2)
# Out:
# 1/1 [==============================] - 0s 139ms/step
# The given image is of
# Class: 0
# Species: ce

# %% [markdown]
# ### Model Xception

# %%
xcep_3 = xcep1_model

# %%
#early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=5) 
mcp_save = ModelCheckpoint('history_Xception_gray_remake2_model.h5', save_best_only=True, monitor='val_loss')

history_Xception_gray_remake_model = xcep_3.fit(
                      training_set_gray,
                      batch_size=4,
                      epochs=100,
                      validation_data = (validation_set_gray),
                      callbacks=[mcp_save]
                      )
# Out:
# Epoch 1/100
# 50/50 [==============================] - 37s 705ms/step - loss: 0.9897 - acc: 0.5758 - val_loss: 1.0656 - val_acc: 0.5060
# Epoch 2/100
# 50/50 [==============================] - 36s 720ms/step - loss: 0.6766 - acc: 0.7525 - val_loss: 0.4315 - val_acc: 0.8367
# Epoch 3/100
# 50/50 [==============================] - 35s 709ms/step - loss: 0.4666 - acc: 0.8232 - val_loss: 0.5396 - val_acc: 0.7769
# Epoch 4/100
# 50/50 [==============================] - 36s 730ms/step - loss: 0.4715 - acc: 0.8081 - val_loss: 0.6217 - val_acc: 0.7570
# Epoch 5/100
# 50/50 [==============================] - 35s 709ms/step - loss: 0.4408 - acc: 0.8232 - val_loss: 0.6202 - val_acc: 0.7570
# Epoch 6/100
# 50/50 [==============================] - 35s 703ms/step - loss: 0.3650 - acc: 0.8737 - val_loss: 0.6329 - val_acc: 0.7331
# Epoch 7/100
# 50/50 [==============================] - 36s 715ms/step - loss: 0.3603 - acc: 0.8687 - val_loss: 0.3770 - val_acc: 0.8606
# Epoch 8/100
# 50/50 [==============================] - 35s 706ms/step - loss: 0.2996 - acc: 0.8990 - val_loss: 0.4522 - val_acc: 0.8088
# Epoch 9/100
# 50/50 [==============================] - 35s 697ms/step - loss: 0.3042 - acc: 0.8889 - val_loss: 0.7266 - val_acc: 0.7291
# Epoch 10/100
# 50/50 [==============================] - 35s 706ms/step - loss: 0.3702 - acc: 0.8586 - val_loss: 0.4185 - val_acc: 0.8486
# Epoch 11/100
# 50/50 [==============================] - 35s 701ms/step - loss: 0.3399 - acc: 0.8889 - val_loss: 0.5463 - val_acc: 0.7769
# Epoch 12/100
# 50/50 [==============================] - 35s 696ms/step - loss: 0.2747 - acc: 0.9242 - val_loss: 0.5681 - val_acc: 0.7689
# Epoch 13/100
# 50/50 [==============================] - 35s 709ms/step - loss: 0.3242 - acc: 0.9141 - val_loss: 0.4609 - val_acc: 0.8327
# Epoch 14/100
# 50/50 [==============================] - 36s 715ms/step - loss: 0.2787 - acc: 0.8838 - val_loss: 0.3292 - val_acc: 0.9004
# Epoch 15/100
# 50/50 [==============================] - 35s 703ms/step - loss: 0.3210 - acc: 0.8687 - val_loss: 0.3553 - val_acc: 0.8845
# Epoch 16/100
# 50/50 [==============================] - 43s 876ms/step - loss: 0.2283 - acc: 0.9141 - val_loss: 0.3572 - val_acc: 0.8845
# Epoch 17/100
# 50/50 [==============================] - 42s 847ms/step - loss: 0.3005 - acc: 0.8838 - val_loss: 0.3513 - val_acc: 0.8685
# Epoch 18/100
# 50/50 [==============================] - 42s 852ms/step - loss: 0.2688 - acc: 0.8939 - val_loss: 0.2876 - val_acc: 0.8884
# Epoch 19/100
# 50/50 [==============================] - 38s 771ms/step - loss: 0.2341 - acc: 0.9293 - val_loss: 0.2664 - val_acc: 0.8964
# %%
show_result(history_Xception_gray_remake_model)
# Out:
# Highest validation accuracy in Epoch: 95
# Train accuracy: 0.9343434572219849
# Validation accuracy: 0.9641434550285339
# --------------------------------------------------
# Last train Epoch
# Train accuracy: 0.9292929172515869
# Validation accuracy: 0.8884462118148804

# %%
xcep_model_remake = models.load_model('history_Xception_gray_remake2_model.h5')
#all_test_df_clahe["label"] = all_test_df_clahe["label"].replace({'Cemento' : 2, 'Ossifying' : 1, 'Fibrous' : 0}) 
#evaluation_report(xcep_model_clahe, test_set_clahe, all_test_df_clahe['label'])

# %%
result_remake2 = xcep_model_remake.evaluate(test_set_gray, verbose=0)

print("Test loss: {:.5f}".format(result_remake2[0]))
print("Test accuracy: {:.2f}".format(result_remake2[1]))
# Out:
# Test loss: 0.67150
# Test accuracy: 0.84

# %% [markdown]
# ### Model efficientnetB 2

# %%
model_effi = tf.keras.applications.efficientnet.EfficientNetB2(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=(260,260,3),
    classifier_activation='softmax'
)
for layer in model_effi.layers:
    layer.trainable = False
x = Flatten() (model_effi.output)
prediction1 = Dense(3, activation = 'softmax')(x)
effi1_model = Model(inputs = model_effi.input, outputs = prediction1)
effi1_model.compile (loss = 'categorical_crossentropy',optimizer = 'adam',metrics = ['acc'])

# %%
effi_3 = effi1_model

# %%
#mcp_save = ModelCheckpoint('history_efficientnet1_1_model_clahe.h5', save_best_only=True, monitor='val_loss')
history_efficientnetB2_gray_remake_model = effi_3.fit(
                      training_set_gray,
                      batch_size=4,
                      epochs=100,
                      validation_data = (validation_set_gray)
                      #callbacks=[mcp_save]
                      )
# Out:
# Epoch 1/100
# 50/50 [==============================] - 32s 528ms/step - loss: 1.0991 - acc: 0.2727 - val_loss: 1.0987 - val_acc: 0.0677
# Epoch 2/100
# 50/50 [==============================] - 25s 502ms/step - loss: 1.0989 - acc: 0.3283 - val_loss: 1.1050 - val_acc: 0.0159
# Epoch 3/100
# 50/50 [==============================] - 25s 498ms/step - loss: 1.0989 - acc: 0.3485 - val_loss: 1.1071 - val_acc: 0.0159
# Epoch 4/100
# 50/50 [==============================] - 26s 513ms/step - loss: 1.0988 - acc: 0.3485 - val_loss: 1.1111 - val_acc: 0.0159
# Epoch 5/100
# 50/50 [==============================] - 25s 492ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1125 - val_acc: 0.0159
# Epoch 6/100
# 50/50 [==============================] - 24s 489ms/step - loss: 1.0987 - acc: 0.3485 - val_loss: 1.1207 - val_acc: 0.0159
# Epoch 7/100
# 50/50 [==============================] - 25s 498ms/step - loss: 1.0987 - acc: 0.3485 - val_loss: 1.1182 - val_acc: 0.0159
# Epoch 8/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1248 - val_acc: 0.0159
# Epoch 9/100
# 50/50 [==============================] - 24s 489ms/step - loss: 1.0983 - acc: 0.3485 - val_loss: 1.1232 - val_acc: 0.0159
# Epoch 10/100
# 50/50 [==============================] - 25s 495ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1247 - val_acc: 0.0159
# Epoch 11/100
# 50/50 [==============================] - 24s 487ms/step - loss: 1.0987 - acc: 0.3485 - val_loss: 1.1241 - val_acc: 0.0159
# Epoch 12/100
# 50/50 [==============================] - 24s 488ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1223 - val_acc: 0.0159
# Epoch 13/100
# 50/50 [==============================] - 25s 506ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1248 - val_acc: 0.0159
# Epoch 14/100
# 50/50 [==============================] - 25s 493ms/step - loss: 1.0982 - acc: 0.3485 - val_loss: 1.1262 - val_acc: 0.0159
# Epoch 15/100
# 50/50 [==============================] - 24s 493ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1256 - val_acc: 0.0159
# Epoch 16/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0986 - acc: 0.3485 - val_loss: 1.1285 - val_acc: 0.0159
# Epoch 17/100
# 50/50 [==============================] - 24s 493ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1286 - val_acc: 0.0159
# Epoch 18/100
# 50/50 [==============================] - 25s 494ms/step - loss: 1.0982 - acc: 0.3485 - val_loss: 1.1262 - val_acc: 0.0159
# Epoch 19/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0983 - acc: 0.3485 - val_loss: 1.1299 - val_acc: 0.0159
# Epoch 20/100
# 50/50 [==============================] - 24s 491ms/step - loss: 1.0982 - acc: 0.3485 - val_loss: 1.1276 - val_acc: 0.0159
# Epoch 21/100
# 50/50 [==============================] - 24s 483ms/step - loss: 1.0987 - acc: 0.3485 - val_loss: 1.1225 - val_acc: 0.0159
# Epoch 22/100
# 50/50 [==============================] - 24s 489ms/step - loss: 1.0983 - acc: 0.3485 - val_loss: 1.1280 - val_acc: 0.0159
# Epoch 23/100
# 50/50 [==============================] - 24s 493ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1300 - val_acc: 0.0159
# Epoch 24/100
# 50/50 [==============================] - 24s 482ms/step - loss: 1.0989 - acc: 0.3485 - val_loss: 1.1369 - val_acc: 0.0159
# Epoch 25/100
# 50/50 [==============================] - 24s 481ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1355 - val_acc: 0.0159
# Epoch 26/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0978 - acc: 0.3485 - val_loss: 1.1357 - val_acc: 0.0159
# Epoch 27/100
# 50/50 [==============================] - 24s 489ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1345 - val_acc: 0.0159
# Epoch 28/100
# 50/50 [==============================] - 24s 488ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1301 - val_acc: 0.0159
# Epoch 29/100
# 50/50 [==============================] - 24s 488ms/step - loss: 1.0989 - acc: 0.3485 - val_loss: 1.1367 - val_acc: 0.0159
# Epoch 30/100
# 50/50 [==============================] - 24s 494ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1340 - val_acc: 0.0159
# Epoch 31/100
# 50/50 [==============================] - 24s 486ms/step - loss: 1.0991 - acc: 0.3485 - val_loss: 1.1328 - val_acc: 0.0159
# Epoch 32/100
# 50/50 [==============================] - 24s 486ms/step - loss: 1.0986 - acc: 0.3485 - val_loss: 1.1325 - val_acc: 0.0159
# Epoch 33/100
# 50/50 [==============================] - 24s 482ms/step - loss: 1.0978 - acc: 0.3535 - val_loss: 1.1305 - val_acc: 0.0159
# Epoch 34/100
# 50/50 [==============================] - 24s 480ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1309 - val_acc: 0.0159
# Epoch 35/100
# 50/50 [==============================] - 24s 483ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1328 - val_acc: 0.0159
# Epoch 36/100
# 50/50 [==============================] - 24s 482ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1293 - val_acc: 0.0159
# Epoch 37/100
# 50/50 [==============================] - 24s 486ms/step - loss: 1.0977 - acc: 0.3485 - val_loss: 1.1278 - val_acc: 0.0159
# Epoch 38/100
# 50/50 [==============================] - 24s 488ms/step - loss: 1.0983 - acc: 0.3485 - val_loss: 1.1275 - val_acc: 0.0159
# Epoch 39/100
# 50/50 [==============================] - 24s 478ms/step - loss: 1.0984 - acc: 0.3434 - val_loss: 1.1328 - val_acc: 0.0159
# Epoch 40/100
# 50/50 [==============================] - 24s 482ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1295 - val_acc: 0.0159
# Epoch 41/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1317 - val_acc: 0.0159
# Epoch 42/100
# 50/50 [==============================] - 24s 486ms/step - loss: 1.0978 - acc: 0.3535 - val_loss: 1.1362 - val_acc: 0.0159
# Epoch 43/100
# 50/50 [==============================] - 24s 483ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1357 - val_acc: 0.0159
# Epoch 44/100
# 50/50 [==============================] - 24s 490ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1334 - val_acc: 0.0159
# Epoch 45/100
# 50/50 [==============================] - 24s 485ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1308 - val_acc: 0.0159
# Epoch 46/100
# 50/50 [==============================] - 27s 533ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1351 - val_acc: 0.0159
# Epoch 47/100
# 50/50 [==============================] - 28s 569ms/step - loss: 1.0984 - acc: 0.3434 - val_loss: 1.1365 - val_acc: 0.0159
# Epoch 48/100
# 50/50 [==============================] - 30s 607ms/step - loss: 1.0980 - acc: 0.3384 - val_loss: 1.1358 - val_acc: 0.0159
# Epoch 49/100
# 50/50 [==============================] - 26s 526ms/step - loss: 1.0977 - acc: 0.3485 - val_loss: 1.1312 - val_acc: 0.0159
# Epoch 50/100
# 50/50 [==============================] - 26s 527ms/step - loss: 1.0977 - acc: 0.3485 - val_loss: 1.1353 - val_acc: 0.0159
# Epoch 51/100
# 50/50 [==============================] - 26s 525ms/step - loss: 1.0976 - acc: 0.3485 - val_loss: 1.1364 - val_acc: 0.0159
# Epoch 52/100
# 50/50 [==============================] - 27s 538ms/step - loss: 1.0980 - acc: 0.3535 - val_loss: 1.1395 - val_acc: 0.0159
# Epoch 53/100
# 50/50 [==============================] - 27s 547ms/step - loss: 1.0977 - acc: 0.3485 - val_loss: 1.1380 - val_acc: 0.0159
# Epoch 54/100
# 50/50 [==============================] - 28s 560ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1364 - val_acc: 0.0159
# Epoch 55/100
# 50/50 [==============================] - 28s 565ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1381 - val_acc: 0.0159
# Epoch 56/100
# 50/50 [==============================] - 28s 558ms/step - loss: 1.0984 - acc: 0.3485 - val_loss: 1.1352 - val_acc: 0.0159
# Epoch 57/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0981 - acc: 0.3535 - val_loss: 1.1354 - val_acc: 0.0159
# Epoch 58/100
# 50/50 [==============================] - 28s 559ms/step - loss: 1.0975 - acc: 0.3485 - val_loss: 1.1382 - val_acc: 0.0159
# Epoch 59/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0983 - acc: 0.3535 - val_loss: 1.1330 - val_acc: 0.0159
# Epoch 60/100
# 50/50 [==============================] - 27s 552ms/step - loss: 1.0977 - acc: 0.3535 - val_loss: 1.1330 - val_acc: 0.0159
# Epoch 61/100
# 50/50 [==============================] - 27s 554ms/step - loss: 1.0968 - acc: 0.3687 - val_loss: 1.1331 - val_acc: 0.0159
# Epoch 62/100
# 50/50 [==============================] - 27s 549ms/step - loss: 1.0987 - acc: 0.3434 - val_loss: 1.1305 - val_acc: 0.0159
# Epoch 63/100
# 50/50 [==============================] - 27s 553ms/step - loss: 1.0980 - acc: 0.3434 - val_loss: 1.1351 - val_acc: 0.0159
# Epoch 64/100
# 50/50 [==============================] - 28s 560ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1370 - val_acc: 0.0159
# Epoch 65/100
# 50/50 [==============================] - 28s 572ms/step - loss: 1.0987 - acc: 0.3535 - val_loss: 1.1300 - val_acc: 0.0159
# Epoch 66/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0976 - acc: 0.3434 - val_loss: 1.1351 - val_acc: 0.0159
# Epoch 67/100
# 50/50 [==============================] - 27s 554ms/step - loss: 1.0989 - acc: 0.3434 - val_loss: 1.1363 - val_acc: 0.0159
# Epoch 68/100
# 50/50 [==============================] - 28s 558ms/step - loss: 1.0972 - acc: 0.3535 - val_loss: 1.1342 - val_acc: 0.0159
# Epoch 69/100
# 50/50 [==============================] - 27s 548ms/step - loss: 1.0971 - acc: 0.3535 - val_loss: 1.1348 - val_acc: 0.0159
# Epoch 70/100
# 50/50 [==============================] - 27s 551ms/step - loss: 1.0981 - acc: 0.3485 - val_loss: 1.1402 - val_acc: 0.0159
# Epoch 71/100
# 50/50 [==============================] - 28s 558ms/step - loss: 1.0984 - acc: 0.3384 - val_loss: 1.1330 - val_acc: 0.0159
# Epoch 72/100
# 50/50 [==============================] - 27s 551ms/step - loss: 1.0968 - acc: 0.3636 - val_loss: 1.1327 - val_acc: 0.0159
# Epoch 73/100
# 50/50 [==============================] - 28s 557ms/step - loss: 1.0971 - acc: 0.3434 - val_loss: 1.1336 - val_acc: 0.0159
# Epoch 74/100
# 50/50 [==============================] - 28s 555ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1318 - val_acc: 0.0159
# Epoch 75/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0984 - acc: 0.3434 - val_loss: 1.1330 - val_acc: 0.0159
# Epoch 76/100
# 50/50 [==============================] - 28s 562ms/step - loss: 1.0989 - acc: 0.3384 - val_loss: 1.1380 - val_acc: 0.0159
# Epoch 77/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0977 - acc: 0.3586 - val_loss: 1.1351 - val_acc: 0.0159
# Epoch 78/100
# 50/50 [==============================] - 28s 567ms/step - loss: 1.0987 - acc: 0.3434 - val_loss: 1.1305 - val_acc: 0.0159
# Epoch 79/100
# 50/50 [==============================] - 28s 559ms/step - loss: 1.0982 - acc: 0.3485 - val_loss: 1.1338 - val_acc: 0.0159
# Epoch 80/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0978 - acc: 0.3485 - val_loss: 1.1341 - val_acc: 0.0159
# Epoch 81/100
# 50/50 [==============================] - 28s 559ms/step - loss: 1.0990 - acc: 0.3434 - val_loss: 1.1314 - val_acc: 0.0159
# Epoch 82/100
# 50/50 [==============================] - 27s 548ms/step - loss: 1.0978 - acc: 0.3485 - val_loss: 1.1335 - val_acc: 0.0159
# Epoch 83/100
# 50/50 [==============================] - 28s 568ms/step - loss: 1.0982 - acc: 0.3485 - val_loss: 1.1344 - val_acc: 0.0159
# Epoch 84/100
# 50/50 [==============================] - 27s 554ms/step - loss: 1.0974 - acc: 0.3586 - val_loss: 1.1299 - val_acc: 0.0159
# Epoch 85/100
# 50/50 [==============================] - 27s 551ms/step - loss: 1.0971 - acc: 0.3535 - val_loss: 1.1287 - val_acc: 0.0159
# Epoch 86/100
# 50/50 [==============================] - 28s 552ms/step - loss: 1.0981 - acc: 0.3434 - val_loss: 1.1308 - val_acc: 0.0159
# Epoch 87/100
# 50/50 [==============================] - 27s 545ms/step - loss: 1.0987 - acc: 0.3434 - val_loss: 1.1313 - val_acc: 0.0159
# Epoch 88/100
# 50/50 [==============================] - 27s 554ms/step - loss: 1.0979 - acc: 0.3485 - val_loss: 1.1291 - val_acc: 0.0159
# Epoch 89/100
# 50/50 [==============================] - 27s 548ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1273 - val_acc: 0.0159
# Epoch 90/100
# 50/50 [==============================] - 28s 553ms/step - loss: 1.0992 - acc: 0.3535 - val_loss: 1.1318 - val_acc: 0.0159
# Epoch 91/100
# 50/50 [==============================] - 28s 559ms/step - loss: 1.0976 - acc: 0.3434 - val_loss: 1.1287 - val_acc: 0.0159
# Epoch 92/100
# 50/50 [==============================] - 27s 553ms/step - loss: 1.0984 - acc: 0.3384 - val_loss: 1.1307 - val_acc: 0.0159
# Epoch 93/100
# 50/50 [==============================] - 28s 559ms/step - loss: 1.0977 - acc: 0.3485 - val_loss: 1.1342 - val_acc: 0.0159
# Epoch 94/100
# 50/50 [==============================] - 27s 551ms/step - loss: 1.0968 - acc: 0.3586 - val_loss: 1.1313 - val_acc: 0.0159
# Epoch 95/100
# 50/50 [==============================] - 27s 553ms/step - loss: 1.0985 - acc: 0.3485 - val_loss: 1.1316 - val_acc: 0.0159
# Epoch 96/100
# 50/50 [==============================] - 28s 560ms/step - loss: 1.0975 - acc: 0.3485 - val_loss: 1.1296 - val_acc: 0.0159
# Epoch 97/100
# 50/50 [==============================] - 28s 556ms/step - loss: 1.0976 - acc: 0.3535 - val_loss: 1.1327 - val_acc: 0.0159
# Epoch 98/100
# 50/50 [==============================] - 28s 562ms/step - loss: 1.0976 - acc: 0.3485 - val_loss: 1.1292 - val_acc: 0.0159
# Epoch 99/100
# 50/50 [==============================] - 27s 554ms/step - loss: 1.0977 - acc: 0.3434 - val_loss: 1.1308 - val_acc: 0.0159
# Epoch 100/100
# 50/50 [==============================] - 27s 553ms/step - loss: 1.0968 - acc: 0.3485 - val_loss: 1.1325 - val_acc: 0.0159

# %%
effi_3.save('effi_gray.h5')

# %%
show_result(history_efficientnetB2_gray_remake_model)
# Out:
# Highest validation accuracy in Epoch: 1
# Train accuracy: 0.27272728085517883
# Validation accuracy: 0.06772908568382263
# --------------------------------------------------
# Last train Epoch
# Train accuracy: 0.3484848439693451
# Validation accuracy: 0.01593625545501709

# %%
effi_model_gray = models.load_model('effi_gray.h5')
#all_test_df_clahe["label"] = all_test_df_clahe["label"].replace({'Cemento' : 2, 'Ossifying' : 1, 'Fibrous' : 0}) 
#evaluation_report(effi_model_clahe, test_set_clahe, all_test_df_clahe['label'])

# %%
result_gray3 = effi_model_gray .evaluate(test_set_gray, verbose=0)

print("Test loss: {:.5f}".format(result_gray3[0]))
print("Test accuracy: {:.2f}".format(result_gray3[1]))
# Out:
# Test loss: 1.09839
# Test accuracy: 0.33

# %%
def predictor2(img, model):
    image = cv2.imread(img)
    image = cv2.resize(image, (260, 260))
    image = np.array(image, dtype = 'float32')/255.0
    plt.imshow(image)
    image = image.reshape(1, 260,260,3)
    
    label_names = label_dict
    dict_class = dict(zip(list(range(len(label_names))), label_names))
    clas = model.predict(image).argmax()
    name = dict_class[clas]
    print('The given image is of \nClass: {0} \nSpecies: {1}'.format(clas, name))

# %%
predictor2('C:\\Users\\CPE\\Desktop\\senior2023\\gray\\test_cell\\os\\os_008_c.png',effi_model_gray)
# Out:
# 1/1 [==============================] - 0s 93ms/step
# The given image is of
# Class: 0
# Species: ce

# %%
#predict_ef('C:\\Users\\CPE\\Desktop\\senior2023\\ossifying_fibroma.jpg',effi_model_clahe)
